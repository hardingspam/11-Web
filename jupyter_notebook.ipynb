# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, Integer, String, MetaData, Float

# %%
medicare_2018 = pd.read_excel(f'bootcamp/project_2/data/Medicare_Provider_Charge_Inpatient_DRGALL_FY2018.xlsx', header=5)
medicare_2018['Year'] = 2018

# %%
medicare_2017 = pd.read_excel(f'bootcamp/project_2/data/Medicare_Provider_Charge_Inpatient_DRGALL_FY2017.xlsx', header=5)
medicare_2017['Year'] = 2017

# %%
medicare_2016 = pd.read_excel(f'bootcamp/project_2/data/Medicare_Provider_Charge_Inpatient_DRGALL_FY2016.xlsx', header=5)
medicare_2016['Year'] = 2016

# %%
medicare_16_17_18 = pd.concat([medicare_2018, medicare_2017, medicare_2016],axis=0)

# %%
medicare_16_17_18.head()
# Out:
#                                       DRG Definition  Provider Id  \
# 0  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        30002
# 1  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        30103
# 2  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        40007
# 3  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        40114
# 4  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        50025
#
#                                        Provider Name  \
# 0         BANNER - UNIVERSITY MEDICAL CENTER PHOENIX
# 1                               MAYO CLINIC HOSPITAL
# 2                           CHI-ST VINCENT INFIRMARY
# 3          BAPTIST HEALTH MEDICAL CENTER-LITTLE ROCK
# 4  UC SAN DIEGO HEALTH HILLCREST - HILLCREST MED CTR
#
#     Provider Street Address Provider City Provider State  Provider Zip Code  \
# 0   1111 EAST MCDOWELL ROAD       PHOENIX             AZ              85006
# 1  5777 EAST MAYO BOULEVARD       PHOENIX             AZ              85054
# 2     TWO ST VINCENT CIRCLE   LITTLE ROCK             AR              72205
# 3           9601 INTERSTATE   LITTLE ROCK             AR              72205
# 4      200 WEST ARBOR DRIVE     SAN DIEGO             CA              92103
#
#   Hospital Referral Region (HRR) Description  Total Discharges  \
# 0                               AZ - Phoenix                12
# 1                               AZ - Phoenix                28
# 2                           AR - Little Rock                11
# 3                           AR - Little Rock                24
# 4                             CA - San Diego                28
#
#    Average Covered Charges  Average Total Payments  Average Medicare Payments  \
# 0            811677.500000           192702.083333              190556.500000
# 1            534977.642857           238997.892857              184659.964286
# 2            652204.272727           161708.090909              158883.909091
# 3            763196.291667           191576.583333              142232.666667
# 4            990536.392857           314883.714286              284554.678571
#
#    Year
# 0  2018
# 1  2018
# 2  2018
# 3  2018
# 4  2018

# %%
medicare_16_17_18['MSDRG'] = medicare_16_17_18['DRG Definition'].apply(lambda x: str(x)[:3]).astype(int)
medicare_16_17_18
# Out:
#                                            DRG Definition  Provider Id  \
# 0       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        30002
# 1       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        30103
# 2       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        40007
# 3       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        40114
# 4       001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        50025
# ...                                                   ...          ...
# 197278  988 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...       520177
# 197279  989 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...       170104
# 197280  989 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...       180088
# 197281  989 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...       220071
# 197282  989 - NON-EXTENSIVE O.R. PROC UNRELATED TO PRI...       360180
#
#                                             Provider Name  \
# 0              BANNER - UNIVERSITY MEDICAL CENTER PHOENIX
# 1                                    MAYO CLINIC HOSPITAL
# 2                                CHI-ST VINCENT INFIRMARY
# 3               BAPTIST HEALTH MEDICAL CENTER-LITTLE ROCK
# 4       UC SAN DIEGO HEALTH HILLCREST - HILLCREST MED CTR
# ...                                                   ...
# 197278               FROEDTERT MEMORIAL LUTHERAN HOSPITAL
# 197279                     SHAWNEE MISSION MEDICAL CENTER
# 197280  NORTON HOSPITAL / NORTON HEALTHCARE PAVILION /...
# 197281                     MASSACHUSETTS GENERAL HOSPITAL
# 197282                                   CLEVELAND CLINIC
#
#          Provider Street Address    Provider City Provider State  \
# 0        1111 EAST MCDOWELL ROAD          PHOENIX             AZ
# 1       5777 EAST MAYO BOULEVARD          PHOENIX             AZ
# 2          TWO ST VINCENT CIRCLE      LITTLE ROCK             AR
# 3                9601 INTERSTATE      LITTLE ROCK             AR
# 4           200 WEST ARBOR DRIVE        SAN DIEGO             CA
# ...                          ...              ...            ...
# 197278      9200 W WISCONSIN AVE        MILWAUKEE             WI
# 197279        9100 W 74TH STREET  SHAWNEE MISSION             KS
# 197280  200 EAST CHESTNUT STREET       LOUISVILLE             KY
# 197281           55 FRUIT STREET           BOSTON             MA
# 197282        9500 EUCLID AVENUE        CLEVELAND             OH
#
#         Provider Zip Code Hospital Referral Region (HRR) Description  \
# 0                   85006                               AZ - Phoenix
# 1                   85054                               AZ - Phoenix
# 2                   72205                           AR - Little Rock
# 3                   72205                           AR - Little Rock
# 4                   92103                             CA - San Diego
# ...                   ...                                        ...
# 197278              53226                             WI - Milwaukee
# 197279              66204                           MO - Kansas City
# 197280              40202                            KY - Louisville
# 197281               2114                                MA - Boston
# 197282              44195                             OH - Cleveland
#
#         Total Discharges  Average Covered Charges  Average Total Payments  \
# 0                     12            811677.500000           192702.083333
# 1                     28            534977.642857           238997.892857
# 2                     11            652204.272727           161708.090909
# 3                     24            763196.291667           191576.583333
# 4                     28            990536.392857           314883.714286
# ...                  ...                      ...                     ...
# 197278                15             63582.800000            22718.866667
# 197279                18             41665.388889             6203.944444
# 197280                12             27916.666667             7571.500000
# 197281                11             54199.636364            10610.181818
# 197282                11             42411.454545             8367.181818
#
#         Average Medicare Payments  Year  MSDRG
# 0                   190556.500000  2018      1
# 1                   184659.964286  2018      1
# 2                   158883.909091  2018      1
# 3                   142232.666667  2018      1
# 4                   284554.678571  2018      1
# ...                           ...   ...    ...
# 197278               17057.866667  2016    988
# 197279                4983.111111  2016    989
# 197280                6487.500000  2016    989
# 197281                9079.090909  2016    989
# 197282                6772.545455  2016    989
#
# [586611 rows x 14 columns]

# %%
msdrg = pd.read_excel(f'/Users/hardings/Desktop/bootcamp/project_2/data/msdrg.xlsx', header=0)
msdrg.rename({'MSDRG ': 'MSDRG'}, axis=1, inplace=True)

# %%
medicare_data = medicare_16_17_18.merge(msdrg, how='left', on='MSDRG')

# %%
medicare_data.columns = medicare_data.columns.str.replace(' ','_')
medicare_data = medicare_data.rename({'Hospital_Referral_Region_(HRR)_Description':'HRR'}, axis = 1)
medicare_data = medicare_data.rename({'Service_Lines_(10)':'Service_Line'}, axis = 1)
medicare_data = medicare_data.rename({'Service_Lines_(20)':'Service_Line_20'}, axis = 1)

medicare_data.head()
# Out:
#                                       DRG_Definition  Provider_Id  \
# 0  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        30002
# 1  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        30103
# 2  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        40007
# 3  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        40114
# 4  001 - HEART TRANSPLANT OR IMPLANT OF HEART ASS...        50025
#
#                                        Provider_Name  \
# 0         BANNER - UNIVERSITY MEDICAL CENTER PHOENIX
# 1                               MAYO CLINIC HOSPITAL
# 2                           CHI-ST VINCENT INFIRMARY
# 3          BAPTIST HEALTH MEDICAL CENTER-LITTLE ROCK
# 4  UC SAN DIEGO HEALTH HILLCREST - HILLCREST MED CTR
#
#     Provider_Street_Address Provider_City Provider_State  Provider_Zip_Code  \
# 0   1111 EAST MCDOWELL ROAD       PHOENIX             AZ              85006
# 1  5777 EAST MAYO BOULEVARD       PHOENIX             AZ              85054
# 2     TWO ST VINCENT CIRCLE   LITTLE ROCK             AR              72205
# 3           9601 INTERSTATE   LITTLE ROCK             AR              72205
# 4      200 WEST ARBOR DRIVE     SAN DIEGO             CA              92103
#
#                 HRR  Total_Discharges  Average_Covered_Charges  ...  MDC  \
# 0      AZ - Phoenix                12            811677.500000  ...  PRE
# 1      AZ - Phoenix                28            534977.642857  ...  PRE
# 2  AR - Little Rock                11            652204.272727  ...  PRE
# 3  AR - Little Rock                24            763196.291667  ...  PRE
# 4    CA - San Diego                28            990536.392857  ...  PRE
#
#    TYPE                                       MS-DRG_Title  Weights  \
# 0  SURG  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...  27.1011
# 1  SURG  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...  27.1011
# 2  SURG  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...  27.1011
# 3  SURG  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...  27.1011
# 4  SURG  HEART TRANSPLANT OR IMPLANT OF HEART ASSIST SY...  27.1011
#
#    Geometric_mean_LOS Arithmetic_mean_LOS    Service_Line  Service_Line_20  \
# 0                30.0                38.6  Cardiovascular  Cardio Thoracic
# 1                30.0                38.6  Cardiovascular  Cardio Thoracic
# 2                30.0                38.6  Cardiovascular  Cardio Thoracic
# 3                30.0                38.6  Cardiovascular  Cardio Thoracic
# 4                30.0                38.6  Cardiovascular  Cardio Thoracic
#
#   Product_Lines_ Weight_Bucket
# 0  CV Transplant            >5
# 1  CV Transplant            >5
# 2  CV Transplant            >5
# 3  CV Transplant            >5
# 4  CV Transplant            >5
#
# [5 rows x 27 columns]

# %%
columns_to_keep = [
    'MSDRG',
    'Provider_Id',
    'Service_Line',
    'Product_Lines_',
    'Geometric_mean_LOS',
    'Arithmetic_mean_LOS',
    'Total_Discharges',
    'Year'
]

medicare_upload_data = medicare_data[columns_to_keep]

# %%
# Create database connection
connection_string = "postgres:postgres@localhost:5432/medicare_drg"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# create table for this data
meta = MetaData()

inpatient = Table(
   'inpatient', meta, 
    Column('MSDRG', Integer),
    Column('Provider_Id', String),
    Column('Service_Line', String),
    Column('Product_Lines_', String),
    Column('Geometric_mean_LOS',Float),
    Column('Arithmetic_mean_LOS',Float),
    Column('Total_Discharges',Integer),
    Column('Year',Integer)

)

meta.create_all(engine)

# %%
# Check table names
engine.table_names()
# Out:
# ['inpatient']

# %%
# Load dataframes into database
medicare_upload_data.to_sql(name='inpatient', con=engine, if_exists='append', index=False)

# %%
# Check to see if data loaded in
pd.read_sql_query('select * from inpatient limit 100', con=engine).head()
# Out:
#    MSDRG Provider_Id    Service_Line Product_Lines_  Geometric_mean_LOS  \
# 0      1       30002  Cardiovascular  CV Transplant                30.0
# 1      1       30103  Cardiovascular  CV Transplant                30.0
# 2      1       40007  Cardiovascular  CV Transplant                30.0
# 3      1       40114  Cardiovascular  CV Transplant                30.0
# 4      1       50025  Cardiovascular  CV Transplant                30.0
#
#    Arithmetic_mean_LOS  Total_Discharges  Year
# 0                 38.6                12  2018
# 1                 38.6                28  2018
# 2                 38.6                11  2018
# 3                 38.6                24  2018
# 4                 38.6                28  2018
